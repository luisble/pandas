# %% [markdown]
# # Pandas

# %% [markdown]
# ### Importação de Bibliotecas

# %%
import pandas as pd
import numpy as np
import pandera as pa
import matplotlib.pyplot as plt

# %% [markdown]
# ### Configuração do ambiente

# %% [markdown]
# #### Configurar o formato de valores com casas decimais

# %%
pd.options.display.float_format  = '{:20,.2f}'.format 
pd.option_context('display.precision', 2)

# %% [markdown]
# #### Configurar o formato de valores com casas decimais no NumPy

# %%
np.set_printoptions(precision=2)

# %% [markdown]
# #### Ou crie uma função e chame ela para exibir o valor

# %%
float_formatter = "{:,.2f}".format 
float_formatter(1500000.043)
# Out:
# '1,500,000.04'

# %% [markdown]
# #### Configurando a quantidade de linhas retornadas

# %%
pd.set_option('display.max_rows', 5) # default é 10
# para versões antigas de pandas há a necessidade de alterar o 
# pd.set_option('display.height', 500)
pd.get_option('display.max_rows')
# Out:
# 5

# %% [markdown]
# #### Configurando o tamanho do retorno da string no Pandas

# %%
pd.set_option('display.max_colwidth',40)
pd.get_option('display.max_colwidth')
# Out:
# 40

# %% [markdown]
# #### Configurando a folha de estilos dos gráficos - Matplotlib

# %%
plt.style.use("seaborn")

# %% [markdown]
# #### Configurando o tamanho do gráfico - Matplotlib

# %%
plt.figure(figsize=(15,5))

# %% [markdown]
# ## Criação de Dataframes e Cargas de Arquivos

# %% [markdown]
# ### Criação de um Dataframe do zero

# %%
# Criando o numpy.array (data) bidimensional
data = np.array([['Analista de Contabilidade', 'Contabilidade', 10000.00],
                ['Analista de Contabilidade', 'Contabilidade', 10000.00],
                ['Engenheiro Civil', 'Engenharia', 15000.00],
                ['Desenvolvedor', 'TI', 11000.00],
                ['Gerente de TI', 'TI',  15000.0],
                ['Analista de BI', 'TI', 13000.0],
                ['DBA', 'TI', 10500.00],
                ['Analista Financeiro', 'Finanças', 10500.00]])

#Criando o DataFrame com o np.array (data) com as colunas ('Cargo', 'Area', 'Salario'), indexado de 100 até 108
dfc = pd.DataFrame(data, index=range(100,108),columns=['Cargo', 'Area', 'Salario'])
dfc
# Out:
#                          Cargo           Area  Salario
# 100  Analista de Contabilidade  Contabilidade  10000.0
# 101  Analista de Contabilidade  Contabilidade  10000.0
# ..                         ...            ...      ...
# 106                        DBA             TI  10500.0
# 107        Analista Financeiro       Finanças  10500.0
#
# [8 rows x 3 columns]

# %% [markdown]
# ### Outra maneira

# %%
data = {'Cargo':  ['Analista de Contabilidade','Analista de Contabilidade','Engenheiro Civil','Desenvolvedor','Gerente de TI', 'Analista de BI','DBA','Analista Financeiro'],
        'Area': ['Contabilidade','Contabilidade','Engenharia','TI','TI','TI','TI','Finanças'],
        'Salario': [10000.00,10000.00,15000.00,11000.00, np.nan, np.nan, 10500.00, 10500.00]
       }
dfcz = pd.DataFrame(data,index=range(100,108), columns=['Cargo','Area','Salario'])

dfcz
# Out:
#                          Cargo           Area              Salario
# 100  Analista de Contabilidade  Contabilidade            10,000.00
# 101  Analista de Contabilidade  Contabilidade            10,000.00
# ..                         ...            ...                  ...
# 106                        DBA             TI            10,500.00
# 107        Analista Financeiro       Finanças            10,500.00
#
# [8 rows x 3 columns]

# %% [markdown]
# ### Carga de arquivo Excel

# %%
dfa = pd.read_excel('Datasets/AdventureWorks.xlsx')
dfa
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0   2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1   2008-05-12 2008-05-17      306         384       19051  200805123CS567
# ..         ...        ...      ...         ...         ...             ...
# 902 2008-12-17 2008-12-21      306        1226       19060  200812174CS676
# 903 2008-12-21 2008-12-25      306        1155       19060  200812214CS676
#
#           Custo Unitário       Preço Unitário  Quantidade  \
# 0                 348.58               758.00           6
# 1                 348.58               758.00           6
# ..                   ...                  ...         ...
# 902               330.99               999.00           6
# 903               324.69               980.00           6
#
#           Valor Desconto          Valor Venda  \
# 0                   0.00             4,548.00
# 1                   0.00             4,548.00
# ..                   ...                  ...
# 902             1,198.80             4,795.20
# 903             1,176.00             4,704.00
#
#                                      Produto       Fabricante  \
# 0      Adventure Works Laptop15.4W M1548 Red  Adventure Works
# 1      Adventure Works Laptop15.4W M1548 Red  Adventure Works
# ..                                       ...              ...
# 902  Fabrikam Trendsetter 1/3'' 8.5mm X20...   Fabrikam, Inc.
# 903  Fabrikam Trendsetter 2/3'' 17mm X100...   Fabrikam, Inc.
#
#                Marca   Classe    Cor
# 0    Adventure Works  Regular    Red
# 1    Adventure Works  Regular    Red
# ..               ...      ...    ...
# 902         Fabrikam  Regular  Black
# 903         Fabrikam  Regular  Black
#
# [904 rows x 16 columns]

# %% [markdown]
# ### Carga oriunda de base de dados MySQL

# %%
# pip install sqlalchemy
# pip install pymysql
from sqlalchemy import create_engine  
import pymysql

sqlHost = '127.0.0.1' 
sqlUser = 'root' 
sqlPwd = 'example' 
sqlBD = 'db_teste' 
db_connection_str = 'mysql+pymysql://{}:{}@{}/{}'.format(sqlUser,sqlPwd,sqlHost,sqlBD) 
db_connection = create_engine(db_connection_str) 
df = pd.read_sql('SELECT id, name, birthday, salary, obs FROM myTable' 
                 , con=db_connection)
df
# Out:
#    id  name    birthday               salary   obs
# 0   1  Luis  1970-04-19               100.00  None
# 1   2  Jack  1968-09-25               120.50  None
# 2   3  Anne  1982-10-02               180.35   CEO

# %% [markdown]
# ### Carga de Arquivos JSON

# %%
# primeiro carrega o arquivo
dscia = pd.read_json('Datasets/companies.json') 
dscia.head()
# Out:
#                                  companies
# 0  {'id': 1, 'company_status_id': None,...
# 1  {'id': 2, 'company_status_id': None,...

# %% [markdown]
# ### Depois normaliza a em dataframe

# %%
df = pd.json_normalize(dscia.companies)
df.head()
# Out:
#    id company_status_id          name king_person document contact phone  \
# 0   1              None    My Company        None     None    None  None
# 1   2              None  Your Company        None     None    None  None
#
#   cell_phone email zipcode address number district  city state created_at  \
# 0       None  None       0    None   None     None  None  None       None
# 1       None  None       0    None   None     None  None  None       None
#
#   updated_at deleted_at
# 0       None       None
# 1       None       None

# %% [markdown]
# ### Também pode ser necessário ler o json por linhas, neste caso utilize o parâmetro lines

# %%
dfbfro = pd.read_json('Datasets/bfro_reports.json', lines=True) 
dfbfro.head()
# Out:
#            YEAR  SEASON          STATE                          COUNTY  \
# 0  Early 1990's    Fall         Alaska  Valdez-Chitina-Whittier County
# 1           NaN     NaN            NaN                             NaN
# 2          2000    Fall     New Jersey                   Warren County
# 3          2016  Summer  New Hampshire                 Sullivan County
# 4          2018  Spring       Nebraska                 Thurston County
#
#                           LOCATION_DETAILS  \
# 0        East side of Prince William Sound
# 1                                      NaN
# 2  the road is off us rt 80, i dont kno...
# 3  Close to Claremont down 120 not far ...
# 4  Latitude & Longitude :  42.158230  -...
#
#                                   OBSERVED  \
# 0  Ed L. was salmon fishing with a comp...
# 1                                      NaN
# 2  heh i kinda feel a little dumb that ...
# 3  I was on my way to Claremont from Le...
# 4  I was northeast of Macy Nebraska alo...
#
#                            OTHER_WITNESSES  \
# 0  On a commercial fishing boat at anch...
# 1                                      NaN
# 2  my friend was asleep, and i was lyin...
# 3                              Just myself
# 4  2 witnesses saw the creature. 3 peop...
#
#                        TIME_AND_CONDITIONS        REPORT_NUMBER REPORT_CLASS  \
# 0         Early Fall, in the early 1990's.             1,261.00      Class A
# 1                                      NaN                  NaN         None
# 2  lighting was from a camp fire that w...               438.00      Class B
# 3                 5am. Dawn. Clear weather            55,269.00      Class A
# 4  1:35 pm on a clear and very hot sunn...            59,757.00      Class B
#
#        MONTH        DATE NEAREST_TOWN          NEAREST_ROAD  \
# 0        NaN         NaN          NaN                   NaN
# 1        NaN         NaN          NaN                   NaN
# 2  September  2nd or 3rd    Allumuchy  not sure of the road
# 3       June           7    Claremont               Rte 120
# 4        May          25         Macy           Highway 201
#
#                               ALSO_NOTICED  \
# 0                                      NaN
# 1                                      NaN
# 2                                  nothing
# 3                                      NaN
# 4  I had audio recorders set up in the ...
#
#                              OTHER_STORIES  \
# 0                                      NaN
# 1                                      NaN
# 2  no but after the events stated i loo...
# 3                                      NaN
# 4  There are MANY encounters in this ge...
#
#                                ENVIRONMENT A_&_G_References
# 0                                      NaN              NaN
# 1                                      NaN              NaN
# 2  good size river, steep hills, very r...              NaN
# 3  swamp with forest behind it. There w...              NaN
# 4  This is a heavily forested area bord...              NaN

# %% [markdown]
# ### Carga de Arquivo CSV - Com validações
#  - sep = Separador
#  - parse_dates = Avalia e transforma em um campo data
#  - dayfirst = Informa que os campos datas tem na primeira parte o valor do dia
#  - na_values = Trasforma os valores identificados nesta lista em valores nulos
#  - decimal = Caracter para reconhecer o ponto decimal
#
#  e validação do schema com a biblioteca **Pandera**

# %%
valores_ausentes = ['**','***','###!','####','****','*****','NULL'] 
dfo = pd.read_csv("Datasets\ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True, na_values=valores_ausentes) 
schema = pa.DataFrameSchema( 
    columns = { 
        "codigo_ocorrencia": pa.Column(pa.Int), 
        "codigo_ocorrencia2": pa.Column(pa.Int), 
        "ocorrencia_classificacao": pa.Column(pa.String), 
        "ocorrencia_cidade": pa.Column(pa.String), 
        "ocorrencia_uf": pa.Column(pa.String, pa.Check.str_length(2,2), nullable=True), 
        "ocorrencia_aerodromo": pa.Column(pa.String, nullable=True), 
        "ocorrencia_dia": pa.Column(pa.DateTime), 
        "ocorrencia_hora": pa.Column(pa.String, pa.Check.str_matches( 
               r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9])(:[0-5][0-9])?$'), nullable=True), 
        "total_recomendacoes": pa.Column(pa.Int), 
        "obs": pa.Column(pa.String, required=False) 
    }    
)

schema.validate(dfo)
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# ...                 ...                 ...                 ...
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# ...                  ...                 ...                      ...
# 5750               79756               79756          INCIDENTE GRAVE
# 5751               79844               79844                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                    NaN                  NaN    RIO DE JANEIRO            RJ
# 1                    NaN                  NaN             BELÉM            PA
# ...                  ...                  ...               ...           ...
# 5750          -22.507222           -54.364167         VICENTINA            MS
# 5751            -22,9875               -43,37    RIO DE JANEIRO            RJ
#
#       ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     ...     2010-01-03        12:00:00                            SIM
# 1     ...     2010-01-03        11:05:00                            SIM
# ...   ...            ...             ...                            ...
# 5750  ...     2020-12-31        09:00:00                            SIM
# 5751  ...     2020-12-31        13:24:00                            SIM
#
#      investigacao_status divulgacao_relatorio_numero  \
# 0             FINALIZADA                         NaN
# 1             FINALIZADA                         NaN
# ...                  ...                         ...
# 5750          FINALIZADA                         NaN
# 5751          FINALIZADA                         NaN
#
#      divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                               NÃO                       NaN
# 1                               NÃO                       NaN
# ...                             ...                       ...
# 5750                            NÃO                       NaN
# 5751                            NÃO                       NaN
#
#      total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                      0                          1                     NÃO
# 1                      0                          1                     NÃO
# ...                  ...                        ...                     ...
# 5750                   0                          1                     NÃO
# 5751                   0                          1                     NÃO
#
# [5752 rows x 22 columns]

# %% [markdown]
# ### Mesmo Dataframe, porém com os valores inconsistentes

# %%
dfoz = pd.read_csv("Datasets\ocorrencia_2010_2020.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True) 
dfoz
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# ...                 ...                 ...                 ...
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# ...                  ...                 ...                      ...
# 5750               79756               79756          INCIDENTE GRAVE
# 5751               79844               79844                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                    ***                  ***    RIO DE JANEIRO            RJ
# 1                    NaN                  NaN             BELÉM            PA
# ...                  ...                  ...               ...           ...
# 5750          -22.507222           -54.364167         VICENTINA            MS
# 5751            -22,9875               -43,37    RIO DE JANEIRO            RJ
#
#       ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     ...     2010-01-03        12:00:00                            SIM
# 1     ...     2010-01-03        11:05:00                            SIM
# ...   ...            ...             ...                            ...
# 5750  ...     2020-12-31        09:00:00                            SIM
# 5751  ...     2020-12-31        13:24:00                            SIM
#
#      investigacao_status divulgacao_relatorio_numero  \
# 0             FINALIZADA                         ***
# 1             FINALIZADA                         NaN
# ...                  ...                         ...
# 5750          FINALIZADA                         ***
# 5751          FINALIZADA                         ***
#
#      divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                               NÃO                       NaN
# 1                               NÃO                       NaN
# ...                             ...                       ...
# 5750                            NÃO                       NaN
# 5751                            NÃO                       NaN
#
#      total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                      0                          1                     NÃO
# 1                      0                          1                     NÃO
# ...                  ...                        ...                     ...
# 5750                   0                          1                     NÃO
# 5751                   0                          1                     NÃO
#
# [5752 rows x 22 columns]

# %% [markdown]
# ### Carga de Arquivo CSV

# %% [markdown]
# #### Com data e hora

# %%
dfr = pd.read_csv('Datasets/reviews.csv',parse_dates=['review_creation_date','review_answer_timestamp'])
dfr
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# ...                                 ...                               ...
# 99998  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 99999  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 4                  NaN
# 1                 5                  NaN
# ...             ...                  ...
# 99998             1                  NaN
# 99999             1                  NaN
#
#                         review_comment_message review_creation_date  \
# 0                                          NaN           2018-01-18
# 1                                          NaN           2018-03-10
# ...                                        ...                  ...
# 99998  Solicitei a compra de uma capa de re...           2017-12-15
# 99999  meu produto chegou e ja tenho que de...           2017-07-03
#
#       review_answer_timestamp
# 0         2018-01-18 21:46:59
# 1         2018-03-11 03:05:13
# ...                       ...
# 99998     2017-12-16 01:29:43
# 99999     2017-07-03 21:01:49
#
# [100000 rows x 7 columns]

# %% [markdown]
# #### Com casas decimais

# %%
df = pd.read_csv('Datasets\Arquivo_Salarios_Colaboradores_2020.csv',sep=';', decimal=',')
df.head()
# Out:
#    Ordem              salario  idade  tempocasa  escolar  qproj_estra  \
# 0      1             8,000.80     25          4       11            1
# 1      2             8,500.17     24          5       11            0
# 2      3             3,350.59     22          1       12            0
# 3      4             9,500.24     28          4       14            1
# 4      5             1,500.63     12          2       12            0
#
#    proj_sustent  proj_6sigma  proj_social           notaavalia
# 0             1            1            0                79.38
# 1             0            1            0                84.13
# 2             0            0            0                46.15
# 3             0            0            1                83.85
# 4             0            0            1                73.64

# %% [markdown]
# ### Concatenando Dataframes

# %%
dfoss = pd.concat([dfo,dfoz])
dfoss
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 40211               40211               40211
# 1                 40349               40349               40349
# ...                 ...                 ...                 ...
# 5750              79756               79756               79756
# 5751              79844               79844               79844
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  40211               40211                INCIDENTE
# 1                  40349               40349                INCIDENTE
# ...                  ...                 ...                      ...
# 5750               79756               79756          INCIDENTE GRAVE
# 5751               79844               79844                INCIDENTE
#
#      ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                    NaN                  NaN    RIO DE JANEIRO            RJ
# 1                    NaN                  NaN             BELÉM            PA
# ...                  ...                  ...               ...           ...
# 5750          -22.507222           -54.364167         VICENTINA            MS
# 5751            -22,9875               -43,37    RIO DE JANEIRO            RJ
#
#       ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 0     ...     2010-01-03        12:00:00                            SIM
# 1     ...     2010-01-03        11:05:00                            SIM
# ...   ...            ...             ...                            ...
# 5750  ...     2020-12-31        09:00:00                            SIM
# 5751  ...     2020-12-31        13:24:00                            SIM
#
#      investigacao_status divulgacao_relatorio_numero  \
# 0             FINALIZADA                         NaN
# 1             FINALIZADA                         NaN
# ...                  ...                         ...
# 5750          FINALIZADA                         ***
# 5751          FINALIZADA                         ***
#
#      divulgacao_relatorio_publicado divulgacao_dia_publicacao  \
# 0                               NÃO                       NaN
# 1                               NÃO                       NaN
# ...                             ...                       ...
# 5750                            NÃO                       NaN
# 5751                            NÃO                       NaN
#
#      total_recomendacoes total_aeronaves_envolvidas  ocorrencia_saida_pista
# 0                      0                          1                     NÃO
# 1                      0                          1                     NÃO
# ...                  ...                        ...                     ...
# 5750                   0                          1                     NÃO
# 5751                   0                          1                     NÃO
#
# [11504 rows x 22 columns]
